# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

# %%
tracking = pd.read_feather('data/tracking.feather')
tracking
# Out:
#             gameId  playId  frameId     p0_dx  p1_dx  p2_dx  p3_dx  p4_dx  \
# 0       2022090800      56        1       NaN    NaN    NaN    NaN    NaN
# 1       2022090800      56        2  0.000000  -0.09  -0.21  -0.02  -0.11
# 2       2022090800      56        3 -0.010002  -0.11  -0.21  -0.02  -0.11
# 3       2022090800      56        4  0.000000  -0.13  -0.20  -0.03  -0.11
# 4       2022090800      56        5  0.000000  -0.15  -0.19  -0.04  -0.13
# ...            ...     ...      ...       ...    ...    ...    ...    ...
# 246590  2022110700    3787      116  0.119999   0.02  -0.07  -0.15   0.02
# 246591  2022110700    3787      117  0.100000   0.03  -0.06  -0.13   0.03
# 246592  2022110700    3787      118  0.070000   0.03  -0.03  -0.12   0.03
# 246593  2022110700    3787      119  0.060001   0.02   0.00  -0.10   0.03
# 246594  2022110700    3787      120  0.039999   0.01   0.03  -0.09   0.02
#
#         p5_dx  p6_dx  p7_dx  p8_dx  p9_dx  p10_dx  p11_dx  p12_dx  p13_dx  \
# ...
