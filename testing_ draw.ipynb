# %%
import pandas as pd
import lib.draw as draw

# %%
games = pd.read_csv(f'data/games.csv')
plays = pd.read_csv(f'data/plays.csv')
players = pd.read_csv(f'data/players.csv')
tracking_df = pd.read_csv(f'data/tracking_week_1.csv')

# %%
gid = 2022091113
pid = 3853

draw.animate_play(games=games, tracking_df=tracking_df,
             play_df=plays, players=players, gameId=gid,
             playId=pid)
